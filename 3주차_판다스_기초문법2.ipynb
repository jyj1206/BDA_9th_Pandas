# %% [markdown]
# <a href="https://colab.research.google.com/github/jyj1206/BDA_9th_Pandas/blob/main/3%EC%A3%BC%EC%B0%A8_%ED%8C%90%EB%8B%A4%EC%8A%A4_%EA%B8%B0%EC%B4%88%EB%AC%B8%EB%B2%952.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 판다스 기초문법

# %% [markdown]
# ## 데이터 전처리 및 추출

# %%
# 데이터 불러오기
import seaborn as sns
import pandas as pd
dia = sns.load_dataset('diamonds')

# %%
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## 데이터 정렬

# %%
dia.sort_values('carat') # 디폴트는 오름차순
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31594   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]

# %%
dia.sort_values('carat', ascending = False) # 내림차순
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31592   0.20  Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31591   0.20  Premium     E     VS2   59.8   62.0    367   3.79   3.77  2.26
# 31601   0.20  Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
# 14      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
#
# [53940 rows x 10 columns]

# %%
# 기준 컬럼이 2개 이상
# 앞 컬럼부터 순서대로 정렬의 기준이 됨
display(dia.sort_values(['carat', 'price']))
display(dia.sort_values(['price', 'carat']))
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 14      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31591   0.20  Premium     E     VS2   59.8   62.0    367   3.79   3.77  2.26
# 31592   0.20  Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31594   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]
# ...

# %%
# 2개 이상의 컬럼도 정렬 기준을 다르게 둘 수 있음
dia.sort_values(['carat', 'price'], ascending = [False, True])
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 25999   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# ...      ...        ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31597   0.20      Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31598   0.20  Very Good     E     VS2   63.4   59.0    367   3.74   3.71  2.36
# 31599   0.20      Ideal     E     VS2   62.2   57.0    367   3.76   3.73  2.33
# 31600   0.20    Premium     D     VS2   62.3   60.0    367   3.73   3.68  2.31
# 31601   0.20    Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
#
# ...

# %% [markdown]
#  ## 데이터 집계

# %%
# 특정 컬럼 클래스별 개수확인
dia.value_counts('cut')
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# 기준컬럼 기준으로 그룹화
cut_gr = dia.groupby('cut')
# Out:
# <ipython-input-53-4d154b877ad6>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cut_gr = dia.groupby('cut')

# %%
# 그룹된 결과 출력(i : 그룹, j : 그룹에 속한 데이터)
for i, j in cut_gr:
  print(i, j)
# Out:
# Ideal        carat    cut color clarity  depth  table  price     x     y     z
# 0       0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11      0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39      0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53925   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53929   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [21551 rows x 10 columns]
# ...

# %%
# 특정 그룹에 해당하는 데이터만 추출
cut_gr.get_group('Premium')
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %%
# 2개 이상으로 묶기
cut_gr = dia.groupby(['cut', 'color'])
# Out:
# <ipython-input-56-31cc3c7a2f8c>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cut_gr = dia.groupby(['cut', 'color'])

# %%
# 그룹된 결과 출력(i : 그룹, j : 그룹에 속한 데이터)
for i, j in cut_gr:
  print(i, j)
# Out:
# ('Ideal', 'D')        carat    cut color clarity  depth  table  price     x     y     z
# 62      0.30  Ideal     D     SI1   62.5   57.0    552  4.29  4.32  2.69
# 63      0.30  Ideal     D     SI1   62.1   56.0    552  4.30  4.33  2.68
# 120     0.71  Ideal     D     SI2   62.3   56.0   2762  5.73  5.69  3.56
# 132     0.71  Ideal     D     SI1   61.9   59.0   2764  5.69  5.72  3.53
# 144     0.71  Ideal     D     SI2   61.6   55.0   2767  5.74  5.76  3.54
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53854   0.51  Ideal     D    VVS2   61.7   56.0   2742  5.16  5.14  3.18
# 53855   0.51  Ideal     D    VVS2   61.3   57.0   2742  5.17  5.14  3.16
# 53884   0.81  Ideal     D     SI1   61.5   57.0   2748  6.00  6.03  3.70
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [2834 rows x 10 columns]
# ...

# %%
# 특정 그룹에 해당하는 데이터만 추출
cut_gr.get_group(('Premium','G'))
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 68      0.31  Premium     G     SI1   61.8   58.0    553  4.35  4.32  2.68
# 85      0.24  Premium     G    VVS1   62.3   59.0    554  3.95  3.92  2.45
# 103     0.75  Premium     G     VS2   61.7   58.0   2760  5.85  5.79  3.59
# 106     0.80  Premium     G     SI1   63.0   59.0   2760  5.90  5.81  3.69
# 140     0.71  Premium     G     VS2   60.9   57.0   2766  5.78  5.75  3.51
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53820   0.71  Premium     G     VS2   63.0   56.0   2735  5.70  5.69  3.59
# 53835   0.70  Premium     G    VVS2   59.6   61.0   2737  5.86  5.78  3.47
# 53867   0.76  Premium     G     VS2   61.8   58.0   2744  5.85  5.89  3.63
# 53880   0.73  Premium     G     VS2   60.7   58.0   2746  5.82  5.87  3.55
# 53888   0.83  Premium     G     SI2   61.6   57.0   2749  6.06  6.02  3.72
#
# [2924 rows x 10 columns]

# %%
# groupby 이후 특정 통계치
dia.groupby('cut', observed=True).agg(price_sum=('price', 'sum'))
# Out:
#            price_sum
# cut
# Ideal       74513487
# Premium     63221498
# Very Good   48107623
# Good        19275009
# Fair         7017600

# %%
# 여러 통계치 한번에 추출
dia.groupby('cut', observed=True).agg(price_sum=('price', 'sum'),
                                      price_mean=('price', 'mean'),
                                      price_std=('price', 'std'),
                                      carat_max=('carat', 'max'),
                                      carat_sum=('carat', 'sum'),
                                      color_count=('color', 'count'))
# Out:
#            price_sum   price_mean    price_std  carat_max  carat_sum  \
# cut
# Ideal       74513487  3457.541970  3808.401172       3.50   15146.84
# Premium     63221498  4584.257704  4349.204961       4.01   12300.95
# Very Good   48107623  3981.759891  3935.862161       4.00    9742.70
# Good        19275009  3928.864452  3681.589584       3.01    4166.10
# Fair         7017600  4358.757764  3560.386612       5.01    1684.28
#
#            color_count
# cut
# Ideal            21551
# Premium          13791
# Very Good        12082
# Good              4906
# Fair              1610

# %%
# 특정 함수를 만들어서 적용 가능하다.
def min_max(x):
    return x.max()- x.min()

# %%
dia[['color','carat','price','depth']].groupby('color', observed=True).agg(min_max)
# Out:
#        carat  price  depth
# color
# D       3.20  18336   19.4
# E       2.85  18405   28.0
# F       2.81  18449   18.7
# G       2.78  18464   29.9
# H       3.90  18466   19.1
# I       3.78  18489   20.5
# J       4.78  18375   30.6

# %%
# 응용 가능
dia.groupby('color', observed=True)['price'].mean()
# Out:
# color
# D    3169.954096
# E    3076.752475
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %% [markdown]
# ## 구간 나누기

# %%
import numpy as np

data = abs(np.random.randn(30)) * 100
data
# Out:
# array([ 84.61372535,  38.52144205,  82.35206866,  88.48528319,
#         46.52952536, 146.26741384,  34.25830479, 113.42894938,
#        281.34463057,  32.35778144,   3.66965888,  21.42605036,
#         46.62711333,  57.66599375,  45.97338141,   8.35167329,
#        294.3641892 ,  83.26997909,  72.75252724, 119.33774393,
#         53.85967594, 154.17388735,  85.14670474, 238.44161546,
#         30.33318709,   5.58698123,  64.20010003,  16.59391426,
#         40.85508076, 121.58888042])

# %%
# 분위수로 나누기
res_qcut = pd.qcut(data, q=5, labels=['매우낮음', '낮음', '중간', '높음', '매우높음'])
res_qcut
# Out:
# ['높음', '낮음', '중간', '높음', '낮음', ..., '매우낮음', '중간', '매우낮음', '낮음', '매우높음']
# Length: 30
# Categories (5, object): ['매우낮음' < '낮음' < '중간' < '높음' < '매우높음']

# %%
# 고정된 값의 구간 나누기
res_cut=pd.cut(data, bins=5, labels=['매우낮음', '낮음','중간','높음','매우높음'])
res_cut
# Out:
# ['낮음', '매우낮음', '낮음', '낮음', '매우낮음', ..., '매우낮음', '낮음', '매우낮음', '매우낮음', '중간']
# Length: 30
# Categories (5, object): ['매우낮음' < '낮음' < '중간' < '높음' < '매우높음']

# %% [markdown]
# ## 사용자 정의 함수 적용

# %%
# apply() 적용
# 함수 정의
def calc_carat_size(carat):
  if carat >= 1:
    return "크다"
  elif carat >= 0.5:
    return "중간크기"
  else:
    return "작다"

dia['carat_size'] = dia['carat'].apply(calc_carat_size)

# %%
# assing() 적용
dia.assign(korean_price = lambda x : x['price'] * 1000)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       carat_size  korean_price
# ...

# %% [markdown]
# ## 데이터 병합

# %%
# 예시 데이터 생성
test1 = pd.DataFrame({
    '과일종류': ['사과', '바나나', '포도', '딸기', '오렌지'],
    '가격': [1000, 1500, 2000, 2500, 1800]
})

test2 = pd.DataFrame({
    '과일종류': ['사과', '바나나', '포도', '딸기', '수박'],
    '수량': [50, 100, 150, 200, 300]
})

# %%
test1
# Out:
#   과일종류    가격
# 0   사과  1000
# 1  바나나  1500
# 2   포도  2000
# 3   딸기  2500
# 4  오렌지  1800

# %%
test2
# Out:
#   과일종류   수량
# 0   사과   50
# 1  바나나  100
# 2   포도  150
# 3   딸기  200
# 4   수박  300

# %%
# 행을 기준으로 concat
pd.concat([test1, test2], axis=0)
# Out:
#   과일종류      가격     수량
# 0   사과  1000.0    NaN
# 1  바나나  1500.0    NaN
# 2   포도  2000.0    NaN
# 3   딸기  2500.0    NaN
# 4  오렌지  1800.0    NaN
# 0   사과     NaN   50.0
# 1  바나나     NaN  100.0
# 2   포도     NaN  150.0
# 3   딸기     NaN  200.0
# 4   수박     NaN  300.0

# %%
# 열을 기준으로 concat
pd.concat([test1, test2], axis=1)
# Out:
#   과일종류    가격 과일종류   수량
# 0   사과  1000   사과   50
# 1  바나나  1500  바나나  100
# 2   포도  2000   포도  150
# 3   딸기  2500   딸기  200
# 4  오렌지  1800   수박  300

# %%
# 과일종류를 기준으로 inner join
pd.merge(test1, test2, on='과일종류', how='inner')
# Out:
#   과일종류    가격   수량
# 0   사과  1000   50
# 1  바나나  1500  100
# 2   포도  2000  150
# 3   딸기  2500  200

# %%
# 과일종류를 기준으로 outer join
pd.merge(test1, test2, on='과일종류', how='outer')
# Out:
#   과일종류      가격     수량
# 0   사과  1000.0   50.0
# 1  바나나  1500.0  100.0
# 2   포도  2000.0  150.0
# 3   딸기  2500.0  200.0
# 4  오렌지  1800.0    NaN
# 5   수박     NaN  300.0
